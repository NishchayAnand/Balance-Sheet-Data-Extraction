# %%
import os
import re
import pandas as pd
import json

# %%
# function to process the extracted financial value (if extracted)
def process_value(value):
    if(value[0]=="{" or value[-1]=="}"):
        return value
    value = value.replace(",", "")
    if(len(value)!=0):
        if(value[0] == "("): 
            value = value.replace("(", "-")
        if(value[-1] == ")"):
            value = value.replace(")", "")
    return value

# %%
def extract_financial_data(file_path):
    
#EXTRACTING LINES FROM THE TEXT FILE.

    line_array=[]
    f = open(file_path, "r")
    for line in f.readlines():
        line_array.append((" ").join(line.split()))

#FIND THE STARTING AND ENDING INDEX OF FINANCIAL DATA AND EXTRACTING THE LINES CONTAINING FINANCIAL DATA..
    
    # most of the files have financial data confined between two lines having "dd Month YYYY" string.
    bounding_regex = re.compile(r'(\d(\d)?\s+)(\w+)\s+\d\d\d\d$') 
    found=False
    bounding_string=''
    for line in line_array:
        match = bounding_regex.search(line)
        if match and found == False:
            bounding_string=match.group()
            found=True

    financial_data=line_array
    if(bounding_string!=''):
        bounding_index=[line_array.index(l) for l in line_array if bounding_string in l] # index of lines containing the bounding string.
        # if bounding string is present at the starting index 
        if(len(bounding_index)==1):
            financial_data=financial_data[bounding_index[0]+1:]
        # if we are able to find the starting and ending index using bounding string.
        if(len(bounding_index)>1):
            financial_data = financial_data[bounding_index[0]+1:bounding_index[1]]
        for line in financial_data:
            # lines having "STATEMENTS" or "INFORMATION" or "NOTES TO THE ACCOUNTS" can act as the ending index for the financial data.
            if("statement" in line.lower() or "information" in line.lower() or "notes to the accounts" in line.lower()):
                financial_data = financial_data[:financial_data.index(line)]
                break
    
    # (optional-does not make any change to the output-just reduces the redundant data-specific to the problem) 
    if(len(financial_data)>15):
        financial_data=financial_data[:15]
    
# CODE TO FIND THE LINE - NOTES|NOTE (OPTIONAL) YEAR1 (OPTIONAL) YEAR2 to find the index of "2019" if it is there in the file

    regex = re.compile(r'((Note|Notes)\s)?((\d){4}\s)?(\d){4}$')
    # str_arr will be of the format [curr_year, prev_year] or [curr_year]
    str_arr=[]
    for line in financial_data:
        match = regex.search(line)
        if match:
            print(line)
            financial_data=financial_data[financial_data.index(line)+2:]
            str_arr=match.group().split()
            if(str_arr[0]=="Notes" or str_arr[0]=="Note"):
                str_arr.pop(0)
            break
            
    print(str_arr)
    print(financial_data)
    print()
    
#EXTRACT THE FINAL DATA AND CREATE A DICTIONARY IF POSSIBLE.

    index=-1
    financial_record={}
    
    # if str_arr is of the format [curr_year, prev_year], then financial data can be of the format:
    if(len(str_arr)==2):
        regex_1=re.compile(r'(.*)\s(\(?[\,\.0-9]+\)?|-)\s(\(?[\,\.0-9]+\)?|-)$') # 1) string Value1 Value2
        regex_2=re.compile(r'(\(?[\,0-9]+\)?|-)\s(\(?[\,0-9]+\)?|-)$') # 2) Value1 Value2
        regex_3=re.compile(r'(.*\s.*)$') # 3) string
        
    # if str_arr is of the format [curr_year], then financial data can be of the format:
    elif(len(str_arr)==1):
        regex_1=re.compile(r'(.*)\s(\(?[\,\.0-9]+\)?|-)$') # 1) string Value1
        regex_2=re.compile(r'(\(?[\,\.0-9]+\)?|-)$') # 2) Value1
        regex_3=re.compile(r'(.*\s.*)$') # 3) string
        
    if(len(str_arr)!=0):
        
        # find the index of "2019" if it is present in the file.
        if '2019' in str_arr:
            index=str_arr.index("2019")
            
        # extracting the label and its corresponding value (if it exists).
        for line in financial_data:
            label='nan'
            value='nan'
            
            if(regex_1.search(line)):
                match=regex_1.search(line)
                label=match.group(1).replace("Â£","&#163").replace("Â$","&#36").replace("Â€","&#8364")
                if(index!=-1):
                    value=process_value(match.group(index+2))
                    
            elif(regex_2.search(line)):
                match=regex_2.search(line)
                if(index!=-1):
                    value=process_value(match.group(index+1))
                    
            elif(regex_3.search(line)):
                match=regex_3.search(line)
                label=match.group(1).replace("Â£","&#163").replace("Â$","&#36").replace("Â€","&#8364")
                
            # appending the label and its value as key-value pair in a dictionary
            financial_record.update({str(label):str(value)})
    else:
        regex_1=re.compile(r'(.*)\s(\(?[\,\.0-9]+\)?|-)\s(\(?[\,\.0-9]+\)?|-)$')
       
    return json.dumps(financial_record)

# %%
def extract_balance_sheets_data(dir_path):
    file_names = os.listdir(dir_path)
    result=pd.DataFrame(columns=["Filename", "Extracted Values"])
    for file in file_names[:100]:
        print()
        print(file)
        extracted_dic = extract_financial_data(os.path.join(dir_path, file))
        print(extracted_dic)
        print()
        print("----------------------------------------------------------------------------------------------")

# %%
#-----------------------------------------------------------------------------------------------------

# %%
dir_path = ".\HCL ML Challenge Dataset"
extract_balance_sheets_data(dir_path)
# Out:
# X8XUG1JD.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current Assets 312 1', 'Creditors: amounts falling due within one year (59) -', 'Net current assets (liabilities) 253 1', 'Total assets less current liabilities 253 1', 'Total net assets (liabilities) 253 1', 'Capital and reserves 253 1']
#
# {"Current Assets": "312", "Creditors: amounts falling due within one year": "-59", "Net current assets (liabilities)": "253", "Total assets less current liabilities": "253", "Total net assets (liabilities)": "253", "Capital and reserves": "253"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX000W.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1000 1000', 'Net assets 1000 1000', 'Issued share capital', '1000 Ordinary Shares 1 of Â£ each 1000 1000', 'Total Shareholder funds 1000 1000']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1000", "Net assets": "1000", "Issued share capital": "nan", "1000 Ordinary Shares 1 of &#163 each": "1000", "Total Shareholder funds": "1000"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX00J6.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid -', 'Fixed Assets 516', 'Current Assets -', 'Prepayments and accrued income -', 'Creditors: amounts falling due within one year 0', 'Net current assets (liabilities) 0', 'Total assets less current liabilities 516', 'Creditors: amounts falling due after more than one year 0', 'Provisions for liabilities 0', 'Accruals and deferred income 0', 'Total net assets (liabilities) 516', 'Capital and reserves 516']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "516", "Current Assets": "-", "Prepayments and accrued income": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "516", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "516", "Capital and reserves": "516"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX00LL.txt
# []
# ['And signed on their behalf by:', 'Jianhong GU, Director', 'This document was delivered using electronic communications and authenticated in accordance with the', "registrar's rules relating to electronic form, authentication and manner of delivery under section 1072 of", 'the Companies Act 2006.']
#
# {}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX00MX.txt
# 2018
# ['2018']
# ['Current assets', 'Cash at bank and in hand 1', 'Net assets 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "nan", "Net assets": "nan", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "nan", "Total Shareholder funds": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX00YW.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid 1,000', 'Current Assets 4,240', 'Creditors: amounts falling due within one year (3,082)', 'Net current assets (liabilities) 1,158', 'Total assets less current liabilities 2,158', 'Total net assets (liabilities) 2,158', 'Capital and reserves 2,158']
#
# {"Called up share capital not paid": "1000", "Current Assets": "4240", "Creditors: amounts falling due within one year": "-3082", "Net current assets (liabilities)": "1158", "Total assets less current liabilities": "2158", "Total net assets (liabilities)": "2158", "Capital and reserves": "2158"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0137.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0196.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 1', 'Net assets 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01EH.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid - -', 'Fixed Assets 1 1', 'Current Assets 254 254', 'Prepayments and accrued income - -', 'Creditors: amounts falling due within one year 0 0', 'Net current assets (liabilities) 254 254', 'Total assets less current liabilities 255 255', 'Creditors: amounts falling due after more than one year 0 0', 'Provisions for liabilities 0 0', 'Accruals and deferred income 0 0', 'Total net assets (liabilities) 255 255', 'Capital and reserves 255 255']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "1", "Current Assets": "254", "Prepayments and accrued income": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "254", "Total assets less current liabilities": "255", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "255", "Capital and reserves": "255"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01EP.txt
# 2020 2019
# ['2020', '2019']
# ['Current assets', 'Cash at bank and in hand 2 2', 'Net assets 2 2', 'Issued share capital', '2 Ordinay Shares of Â£ | each 2 2', 'Total Shareholder funds 2 2']
#
# {"Current assets": "nan", "Cash at bank and in hand": "2", "Net assets": "2", "Issued share capital": "nan", "2 Ordinay Shares of &#163 | each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01IX.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Fixed Assets 18,812 1', 'Current Assets 87,198 55,690', 'Creditors: amounts falling due within one year (151,460) (101,141)', 'Net current assets (liabilities) (64,262) (45,451)', 'Total assets less current liabilities (45,449) (45,449)', 'Total net assets (liabilities) (45,449) (45,449)', 'Capital and reserves (45,449) (45,449)']
#
# {"Called up share capital not paid": "1", "Fixed Assets": "18812", "Current Assets": "87198", "Creditors: amounts falling due within one year": "-151460", "Net current assets (liabilities)": "-64262", "Total assets less current liabilities": "-45449", "Total net assets (liabilities)": "-45449", "Capital and reserves": "-45449"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01SZ.txt
# 2020
# ['2020']
# ['Called up share capital not paid 2', 'Net assets 2', 'Tssued share capital', '2 Ordinary Shares 1 of Â£ each 2', 'Total Shareholder funds 2']
#
# {"Called up share capital not paid": "nan", "Net assets": "nan", "Tssued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "nan", "Total Shareholder funds": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01TN.txt
# 2019
# ['2019']
# ['Called up share capital not paid 2', 'Net assets 2', 'Tssued share capital', '2 Ordinary Shares 1 of Â£ each 2', 'Total Shareholder funds 2']
#
# {"Called up share capital not paid": "2", "Net assets": "2", "Tssued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX01TV.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX02AX.txt
# 2019 2018
# ['2019', '2018']
# ['Net assets 0 0', 'Issued share capital', '1 Ordinary Share 0 of Â£ each 0 0', 'Total Shareholder funds 0 0']
#
# {"Net assets": "0", "Issued share capital": "nan", "1 Ordinary Share 0 of &#163 each": "0", "Total Shareholder funds": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX02N7.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current Assets 5,751 5,751', 'Net current assets (liabilities) 5,751 5,751', 'Total assets less current liabilities 5,751 5,751', 'Creditors: amounts falling due after more than one', '2.,531) (2.531)', 'year', 'Total net assets (liabilities) 3,220 3,220', 'Capital and reserves 3,220 3,220']
#
# {"Current Assets": "5751", "Net current assets (liabilities)": "5751", "Total assets less current liabilities": "5751", "Creditors: amounts falling due after more than one": "nan", "2.,531) (2.531)": "nan", "nan": "nan", "Total net assets (liabilities)": "3220", "Capital and reserves": "3220"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX02SY.txt
# Notes 2019
# ['2019']
# ['Current Assets 8,312', 'Creditors: amounts falling due within one year (5,606)', 'Net current assets (liabilities) 2,706', 'Total assets less current liabilities 2,706', 'Total net assets (liabilities) 2,706', 'Capital and reserves 2,706']
#
# {"Current Assets": "8312", "Creditors: amounts falling due within one year": "-5606", "Net current assets (liabilities)": "2706", "Total assets less current liabilities": "2706", "Total net assets (liabilities)": "2706", "Capital and reserves": "2706"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX036G.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets - 202', 'Current Assets - 10,833', 'Creditors: amounts falling due within one year 0 (2,466)', 'Net current assets (liabilities) 0 8367', 'Total assets less current liabilities 0 8,569', 'Creditors: amounts falling due after more than one year 0 (5,083)', 'Total net assets (liabilities) 0 3486', 'Capital and reserves 0 3,486']
#
# {"Fixed Assets": "-", "Current Assets": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "0", "Creditors: amounts falling due after more than one year": "0", "Total net assets (liabilities)": "0", "Capital and reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX03IJ.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares of Â£ | each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares of &#163 | each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX03S9.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 100', 'Net assets 100', 'Issued share capital', '100 A Shares 1 of Â£ each 100', 'Total Shareholder funds 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 A Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX07H7.txt
# Notes 2016
# ['2016']
# ['Current Assets -', 'Prepayments and accrued income -', 'Creditors: amounts falling due within one year 0', 'Net current assets (liabilities) 0', 'Total assets less current liabilities 0', 'Creditors: amounts falling due after more than one year 0', 'Total net assets (liabilities) 0', 'Capital and reserves 0']
#
# {"Current Assets": "nan", "Prepayments and accrued income": "nan", "Creditors: amounts falling due within one year": "nan", "Net current assets (liabilities)": "nan", "Total assets less current liabilities": "nan", "Creditors: amounts falling due after more than one year": "nan", "Total net assets (liabilities)": "nan", "Capital and reserves": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0ANN.txt
# 2020 2019
# ['2020', '2019']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0BU1.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 100 100', 'Net assets 100 100', 'Issued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0C57.txt
# 2020 2019
# ['2020', '2019']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XX0CEA.txt
# Notes 2019
# ['2019']
# ['Current Assets 384', 'Creditors: amounts falling due within one year (225)', 'Net current assets (liabilities) 159', 'Total assets less current liabilities 159', 'Total net assets (liabilities) 159', 'Capital and reserves 159']
#
# {"Current Assets": "384", "Creditors: amounts falling due within one year": "-225", "Net current assets (liabilities)": "159", "Total assets less current liabilities": "159", "Total net assets (liabilities)": "159", "Capital and reserves": "159"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZI954.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 0.00 0.00', 'Current assets', 'Cash at bank and in hand 100.00 100.00', 'Net assets 100.00 100.00', 'Issued share capital', '100 Ordinary Shares of Â£1.00 each 100.00 100.00', 'Total Shareholder funds 100.00 100.00']
#
# {"Called up share capital not paid": "0.00", "Current assets": "nan", "Cash at bank and in hand": "100.00", "Net assets": "100.00", "Issued share capital": "nan", "100 Ordinary Shares of &#1631.00 each": "100.00", "Total Shareholder funds": "100.00"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZI9MH.txt
# Notes 2020 2019
# ['2020', '2019']
# ['Called up share capital not paid - -', 'Fixed Assets 100,000 -', 'Current Assets 300,000 500,000', 'Prepayments and accrued income 150,000 -', 'Net current assets (liabilities) 450,000 500,000', 'Total assets less current liabilities 550,000 500,000', 'Total net assets (liabilities) 550,000 500,000', 'Capital and reserves 550,000 500,000']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "-", "Current Assets": "500000", "Prepayments and accrued income": "-", "Net current assets (liabilities)": "500000", "Total assets less current liabilities": "500000", "Total net assets (liabilities)": "500000", "Capital and reserves": "500000"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZI9Y0.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 578 770', 'Current assets 112,532 98,600', 'Creditors: amounts falling due within one year (21,596) {15,032)', 'Net current assets 90,936 83,568', 'Total assets less current liabilities 91,514 84,338', 'Accruals and deferred income (3,850) (3,850)', 'Net assets 87,604 80,488', 'Capital and reserves 87,664 80,488']
#
# {"Fixed assets": "578", "Current assets": "112532", "Creditors: amounts falling due within one year (21,596) {15,032)": "nan", "Net current assets": "90936", "Total assets less current liabilities": "91514", "Accruals and deferred income": "-3850", "Net assets": "87604", "Capital and reserves": "87664"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIB3U.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid -', 'Fixed Assets 780', 'Current Assets 2,942', 'Creditors: amounts falling due within one year (5,690)', 'Net current assets (liabilities) (2,748)', 'Total assets less current liabilities (1,968)', 'Total net assets (liabilities) (1,968)', 'Capital and reserves (1,968)']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "780", "Current Assets": "2942", "Creditors: amounts falling due within one year": "-5690", "Net current assets (liabilities)": "-2748", "Total assets less current liabilities": "-1968", "Total net assets (liabilities)": "-1968", "Capital and reserves": "-1968"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIBDK.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 5 5', 'Fixed Assets - -', 'Current Assets - -', 'Prepayments and accrued income - -', 'Creditors: amounts falling due within one year 0 0', 'Net current assets (liabilities) 0 0', 'Total assets less current liabilities 5 5', 'Creditors: amounts falling due after more than one year 0 0', 'Provisions for liabilities 0 0', 'Accruals and deferred income 0 0', 'Total net assets (liabilities) 5 5', 'Capital and reserves 5 5']
#
# {"Called up share capital not paid": "5", "Fixed Assets": "-", "Current Assets": "-", "Prepayments and accrued income": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "5", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "5", "Capital and reserves": "5"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIBOZ.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid 1', 'Fixed Assets 23,000', 'Current Assets 15,474', 'Creditors: amounts falling due within one year (35,344)', 'Net current assets (liabilities) (19,870)', 'Total assets less current liabilities 3,131', 'Total net assets (liabilities) 3,131', 'Capital and reserves 3,131']
#
# {"Called up share capital not paid": "1", "Fixed Assets": "23000", "Current Assets": "15474", "Creditors: amounts falling due within one year": "-35344", "Net current assets (liabilities)": "-19870", "Total assets less current liabilities": "3131", "Total net assets (liabilities)": "3131", "Capital and reserves": "3131"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIBXE.txt
# 2019 2018
# ['2019', '2018']
# ['Net assets 0 0', 'Reserves 0 0']
#
# {"Net assets": "0", "Reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIBZD.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Current Assets 1,016 1,015', 'Net current assets (liabilities) 1,016 1,015', 'Total assets less current liabilities 1,017 1,016', 'Total net assets (liabilities) 1,017 1,016', 'Capital and reserves 1,017 1,016']
#
# {"Called up share capital not paid": "1", "Current Assets": "1016", "Net current assets (liabilities)": "1016", "Total assets less current liabilities": "1017", "Total net assets (liabilities)": "1017", "Capital and reserves": "1017"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZICIB.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 100 100', 'Net assets 100 100', 'Issued share capital', '100 Ordinary Shares of Â£ | each 100 100', 'Total Shareholder funds 100 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 Ordinary Shares of &#163 | each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZICNE.txt
# 2020 2019
# ['2020', '2019']
# ['Current assets', 'Cash at bank and in hand 100 100', 'Net assets 100 100', 'Issued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZICQX.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIDG2.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid -', 'Fixed Assets -', 'Current Assets -', 'Net current assets (liabilities) 0', 'Total assets less current liabilities 0', 'Total net assets (liabilities) 0', 'Capital and reserves 0']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "-", "Current Assets": "-", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "0", "Total net assets (liabilities)": "0", "Capital and reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIDMH.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIE17.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '1 Ordinary Share of Â£ 100 each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "1 Ordinary Share of &#163 100 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIEI1.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 13,251 16,564', 'Current assets 4,182 5,731', 'Creditors: amounts falling due within', 'one year 2,463 71', 'Net current assets 6,645 6,442', 'Total assets less current liabilities 19,896 23,006', 'Creditors: amounts falling due after', 'more than one year (3,779) (7,820)', 'Accruals and deferred income (450) (450)', 'Net assets 15,667 14,736', 'Capital and reserves 15,667 14,736', '', '']
#
# {"Fixed assets": "13251", "Current assets": "4182", "Creditors: amounts falling due within": "nan", "one year": "2463", "Net current assets": "6645", "Total assets less current liabilities": "19896", "Creditors: amounts falling due after": "nan", "more than one year": "-3779", "Accruals and deferred income": "-450", "Net assets": "15667", "Capital and reserves": "15667", "nan": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIF16.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current Assets 2,386 5,369', 'Creditors: amounts falling due within one year (360) (1,285)', 'Net current assets (liabilities) 2,026 4,084', 'Total assets less current liabilities 2,026 4,084', 'Total net assets (liabilities) 2,026 4,084', 'Capital and reserves 2,026 4,084']
#
# {"Current Assets": "2386", "Creditors: amounts falling due within one year": "-360", "Net current assets (liabilities)": "2026", "Total assets less current liabilities": "2026", "Total net assets (liabilities)": "2026", "Capital and reserves": "2026"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIFE8.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 5 5', 'Net assets 5 5', 'Issued share capital', '5 Ordinary Shares 1 of Â£ each 5 5', 'Total Shareholder funds 5 5']
#
# {"Current assets": "nan", "Cash at bank and in hand": "5", "Net assets": "5", "Issued share capital": "nan", "5 Ordinary Shares 1 of &#163 each": "5", "Total Shareholder funds": "5"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIFNV.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 2,456 2,845', 'Current Assets 212,740 176,642', 'Creditors: amounts falling due within one year (65,764) (64,698)', 'Net current assets (liabilities) 146,976 111,944', 'Total assets less current liabilities 149,432 114,789', 'Provisions for liabilities (467) (541)', 'Total net assets (liabilities) 148,965 114,248', 'Capital and reserves 148,965 114,248']
#
# {"Fixed Assets": "2456", "Current Assets": "212740", "Creditors: amounts falling due within one year": "-65764", "Net current assets (liabilities)": "146976", "Total assets less current liabilities": "149432", "Provisions for liabilities": "-467", "Total net assets (liabilities)": "148965", "Capital and reserves": "148965"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIFZL.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIG2X.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 200 200', 'Net assets 200 200', 'Tssued share capital', '200 Ordinary Shares 1 of Â£ each 200 200', 'Total Shareholder funds 200 200']
#
# {"Called up share capital not paid": "200", "Net assets": "200", "Tssued share capital": "nan", "200 Ordinary Shares 1 of &#163 each": "200", "Total Shareholder funds": "200"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIGW8.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 12,000 14,000', 'Current assets 2191 1,820', 'Creditors: amounts falling due within', 'one year (16,080) (15,732)', 'Net current liabilities (13,889) (13,912)', 'Total assets less current liabilities (1,889) 88', 'Creditors: amounts falling due after', 'more than one year (6,200) (10,681)', 'Net liabilities (8,089) (10,593)', 'Capital and reserves (8,089) (10,593)', 'Number Number', 'Average number of employee 2 2', 'The company is a private company limited by shares and incorporated in Scotland. Its registered office']
#
# {"Fixed assets": "12000", "Current assets": "2191", "Creditors: amounts falling due within": "nan", "one year": "-16080", "Net current liabilities": "-13889", "Total assets less current liabilities": "-1889", "Creditors: amounts falling due after": "nan", "more than one year": "-6200", "Net liabilities": "-8089", "Capital and reserves": "-8089", "Number Number": "nan", "Average number of employee": "2", "The company is a private company limited by shares and incorporated in Scotland. Its registered office": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIIRN.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIIW2.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIIYQ.txt
# 2020 2019
# ['2020', '2019']
# ['Net assets 0 0', 'Reserves 0 0']
#
# {"Net assets": "0", "Reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIJC8.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares of Â£ | each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares of &#163 | each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIKDF.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid 4', 'Current Assets 7,078', 'Creditors: amounts falling due within one year (7,047)', 'Net current assets (liabilities) 31', 'Total assets less current liabilities 35', 'Total net assets (liabilities) 35', 'Capital and reserves 35']
#
# {"Called up share capital not paid": "4", "Current Assets": "7078", "Creditors: amounts falling due within one year": "-7047", "Net current assets (liabilities)": "31", "Total assets less current liabilities": "35", "Total net assets (liabilities)": "35", "Capital and reserves": "35"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIKJ6.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 100 100', 'Net assets 100 100', 'Issued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIKOX.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 8,460 13,082', 'Current Assets 22,756 13,133', 'Creditors: amounts falling due within one year (27,702) (25,263)', 'Net current assets (liabilities) (4,946) (12,130)', 'Total assets less current liabilities 3,514 952', 'Total net assets (liabilities) 3,514 952', 'Capital and reserves 3,514 952']
#
# {"Fixed Assets": "8460", "Current Assets": "22756", "Creditors: amounts falling due within one year": "-27702", "Net current assets (liabilities)": "-4946", "Total assets less current liabilities": "3514", "Total net assets (liabilities)": "3514", "Capital and reserves": "3514"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIMDT.txt
# Notes 2018
# ['2018']
# ['Called up share capital not paid -', 'Fixed Assets -', 'Current Assets 52,100', 'Net current assets (liabilities) 52,100', 'Total assets less current liabilities 52,100', 'Creditors: amounts falling due after more than one year (52,000)', 'Total net assets (liabilities) 100', 'Capital and reserves 100']
#
# {"Called up share capital not paid": "nan", "Fixed Assets": "nan", "Current Assets": "nan", "Net current assets (liabilities)": "nan", "Total assets less current liabilities": "nan", "Creditors: amounts falling due after more than one year": "nan", "Total net assets (liabilities)": "nan", "Capital and reserves": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIMKG.txt
# Notes 2019
# ['2019']
# ['Current Assets 196', 'Creditors: amounts falling due within one year (18)', 'Net current assets (liabilities) 178', 'Total assets less current liabilities 178', 'Total net assets (liabilities) 178', 'Capital and reserves 178']
#
# {"Current Assets": "196", "Creditors: amounts falling due within one year": "-18", "Net current assets (liabilities)": "178", "Total assets less current liabilities": "178", "Total net assets (liabilities)": "178", "Capital and reserves": "178"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIML4.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 50 50', 'Net assets 50 50', 'Issued share capital', '50 Preference Shares 1 of Â£ each 50 50', 'Total Shareholder funds 50 50']
#
# {"Current assets": "nan", "Cash at bank and in hand": "50", "Net assets": "50", "Issued share capital": "nan", "50 Preference Shares 1 of &#163 each": "50", "Total Shareholder funds": "50"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIMQ3.txt
# 2020
# ['2020']
# ['Called up share capital not paid 1', 'Net assets 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Called up share capital not paid": "nan", "Net assets": "nan", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "nan", "Total Shareholder funds": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIN35.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 2 2', 'Net assets 2 2', 'Tssued share capital', '2 Ordinary Shares 1 of Â£ each 2 2', 'Total Shareholder funds 2 2']
#
# {"Called up share capital not paid": "2", "Net assets": "2", "Tssued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZINN6.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZINW9.txt
# 2019
# ['2019']
# ['Called up share capital not paid 1', 'Net assets 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIO5G.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 576 720', 'Current assets 2,020 2,288', 'Creditors: Amounts falling due within one year (8,895) (7,592)', 'Net current liabilities (6.875) (5,304)', 'Total assets less current liabilities (6,299) (4,584)', 'Accruals and deferred income (312) (420)', '(6,611) (5,004)', 'Capital and reserves (6,611) (5,004)']
#
# {"Fixed assets": "576", "Current assets": "2020", "Creditors: Amounts falling due within one year": "-8895", "Net current liabilities": "-6.875", "Total assets less current liabilities": "-6299", "Accruals and deferred income": "-312", "nan": "-6611", "Capital and reserves": "-6611"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIOFU.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 7,264 7,809', 'Current Assets 14,291 30,481', 'Creditors: amounts falling due within one year (563) (3,864)', 'Net current assets (liabilities) 13,728 26,617', 'Total assets less current liabilities 20,992 34,426', 'Total net assets (liabilities) 20,992 34,426', 'Capital and reserves 20,992 34,426']
#
# {"Fixed Assets": "7264", "Current Assets": "14291", "Creditors: amounts falling due within one year": "-563", "Net current assets (liabilities)": "13728", "Total assets less current liabilities": "20992", "Total net assets (liabilities)": "20992", "Capital and reserves": "20992"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIOKY.txt
# Notes 2019
# ['2019']
# ['Current Assets 10,000', 'Net current assets (liabilities) 10,000', 'Total assets less current liabilities 10,000', 'Total net assets (liabilities) 10,000', 'Capital and reserves 10,000']
#
# {"Current Assets": "10000", "Net current assets (liabilities)": "10000", "Total assets less current liabilities": "10000", "Total net assets (liabilities)": "10000", "Capital and reserves": "10000"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIOV4.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 A Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 A Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIOXK.txt
# 2019
# ['2019']
# ['Called up share capital not paid 1', 'Net assets 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIP1V.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 2 - -', '', '', 'Creditors: amounts falling', 'due within one year 5 - -', 'Net current assets - -', 'Net assets - -', 'Capital and reserves', 'Called up share capital 3 - -', 'Shareholders funds - -', 'The director arc satisfied that the company is cntitled to exemption from the requirement to', 'obtain an audit under section 477 of the Companies Act 2006.']
#
# {"Current assets": "nan", "Cash at bank and in hand 2": "-", "nan": "nan", "Creditors: amounts falling": "nan", "due within one year 5": "-", "Net current assets": "-", "Net assets": "-", "Capital and reserves": "nan", "Called up share capital 3": "-", "Shareholders funds": "-", "The director arc satisfied that the company is cntitled to exemption from the requirement to": "nan", "obtain an audit under section 477 of the Companies Act 2006.": "nan"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIPBM.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 83,750 88,750', 'Current Assets 93,152 110,263', 'Creditors: amounts falling due within one year (29,819) (32,441)', 'Net current assets (liabilities) 63,333 77,822', 'Total assets less current liabilities 147,083 166,572', 'Creditors: amounts falling due after more than one', '(37.070) (42.811)', 'year', 'Total net assets (liabilities) 110,013 123,761', 'Capital and reserves 110,013 123,761']
#
# {"Fixed Assets": "83750", "Current Assets": "93152", "Creditors: amounts falling due within one year": "-29819", "Net current assets (liabilities)": "63333", "Total assets less current liabilities": "147083", "Creditors: amounts falling due after more than one": "nan", "(37.070) (42.811)": "nan", "nan": "nan", "Total net assets (liabilities)": "110013", "Capital and reserves": "110013"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIPGP.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 100 Shares 1 of Â£ each 100 100', 'Total Shareholder funds ___ 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 100 Shares 1 of &#163 each": "100", "Total Shareholder funds ___": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIPWZ.txt
# Notes 2020 2019
# ['2020', '2019']
# ['Called up share capital not paid - -', 'Fixed Assets - -', 'Current Assets - -', 'Prepayments and accrued income - -', 'Creditors: amounts falling due within one year 0 0', 'Net current assets (liabilities) 0 0', 'Total assets less current liabilities 0 0', 'Creditors: amounts falling due after more than one year 0 0', 'Provisions for liabilities - 0', 'Accruals and deferred income 0 0', 'Total net assets (liabilities) 0 0', 'Capital and reserves 0 0']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "-", "Current Assets": "-", "Prepayments and accrued income": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "0", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "0", "Capital and reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIQ16.txt
# Notes 2020 2019
# ['2020', '2019']
# ['Current Assets 4450 22,560', 'Creditors: amounts falling due within one year (4,350) (2,038)', 'Net current assets (liabilities) 100 20,522', 'Total assets less current liabilities 100 20,522', 'Total net assets (liabilities) 100 20,522', 'Capital and reserves 100 20,522']
#
# {"Current Assets": "22560", "Creditors: amounts falling due within one year": "-2038", "Net current assets (liabilities)": "20522", "Total assets less current liabilities": "20522", "Total net assets (liabilities)": "20522", "Capital and reserves": "20522"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIQEG.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIR1E.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 46,754 46,754', 'Current Assets 8,017 8,268', 'Creditors: amounts falling due within one year (65,151) (64,798)', 'Net current assets (liabilities) (57,134) (56,530)', 'Total assets less current liabilities (10,380) (9,776)', 'Provisions for liabilities (7,458) (7,458)', 'Accruals and deferred income (1,200) (1,200)', 'Total net assets (liabilities) (19,038) (18,434)', 'Capital and reserves (19,038) (18,434)']
#
# {"Fixed Assets": "46754", "Current Assets": "8017", "Creditors: amounts falling due within one year": "-65151", "Net current assets (liabilities)": "-57134", "Total assets less current liabilities": "-10380", "Provisions for liabilities": "-7458", "Accruals and deferred income": "-1200", "Total net assets (liabilities)": "-19038", "Capital and reserves": "-19038"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIR3U.txt
# Notes 2019
# ['2019']
# ['Fixed Assets 8,326', 'Current Assets 17,380', 'Creditors: amounts falling due within one year (23,723)', 'Net current assets (liabilities) (6,343)', 'Total assets less current liabilities 1,983', 'Total net assets (liabilities) 1,983', 'Capital and reserves 1,983']
#
# {"Fixed Assets": "8326", "Current Assets": "17380", "Creditors: amounts falling due within one year": "-23723", "Net current assets (liabilities)": "-6343", "Total assets less current liabilities": "1983", "Total net assets (liabilities)": "1983", "Capital and reserves": "1983"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIR7V.txt
# Notes 2020 2019
# ['2020', '2019']
# ['Fixed Assets 25,000 25,000', 'Current Assets - -', 'Net current assets (liabilities) 0 0', 'Total assets less current liabilities 25,000 25,000', 'Creditors: amounts falling due after more than one', '(24.998) (24.998)', 'year', 'Total net assets (liabilities) 2 2', 'Capital and reserves 2 2']
#
# {"Fixed Assets": "25000", "Current Assets": "-", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "25000", "Creditors: amounts falling due after more than one": "nan", "(24.998) (24.998)": "nan", "nan": "nan", "Total net assets (liabilities)": "2", "Capital and reserves": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIRI8.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid -', 'Fixed Assets -', 'Current Assets 24,404', 'Creditors: amounts falling due within one year (26,602)', 'Net current assets (liabilities) (2,198)', 'Total assets less current liabilities (2,198)', 'Creditors: amounts falling due after more than one year 0', 'Provisions for liabilities 0', 'Accruals and deferred income 0', 'Total net assets (liabilities) (2,198)', 'Capital and reserves (2,198)']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "-", "Current Assets": "24404", "Creditors: amounts falling due within one year": "-26602", "Net current assets (liabilities)": "-2198", "Total assets less current liabilities": "-2198", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "-2198", "Capital and reserves": "-2198"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIS17.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 2 2', 'Net assets 2 2', 'Tssued share capital', '2 Ordinary Shares 1 of Â£ each 2 2', 'Total Shareholder funds 2 2']
#
# {"Called up share capital not paid": "2", "Net assets": "2", "Tssued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIS4B.txt
# Notes 2019
# ['2019']
# ['Fixed Assets 960', 'Current Assets 1,541', 'Creditors: amounts falling due within one year (1,209)', 'Net current assets (liabilities) 332', 'Total assets less current liabilities 1,292', 'Total net assets (liabilities) 1,292', 'Capital and reserves 1,292']
#
# {"Fixed Assets": "960", "Current Assets": "1541", "Creditors: amounts falling due within one year": "-1209", "Net current assets (liabilities)": "332", "Total assets less current liabilities": "1292", "Total net assets (liabilities)": "1292", "Capital and reserves": "1292"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIS7K.txt
# 2020 2019
# ['2020', '2019']
# ['Current assets - 5,527', 'Creditors: amounts falling due within one year - (4,247)', 'Net current assets - 1,280', 'Total assets less current liabilities - 1,280', 'Accruals and deferred income - (1,273)', 'Net assets - 7', 'Capital and reserves - 7']
#
# {"Current assets": "5527", "Creditors: amounts falling due within one year": "-4247", "Net current assets": "1280", "Total assets less current liabilities": "1280", "Accruals and deferred income": "-1273", "Net assets": "7", "Capital and reserves": "7"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZISVF.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 20 20', 'Net assets 20 20', 'Issued share capital', '20 Ordinary Shares 1 of Â£ each 20 20', 'Total Shareholder funds 20 20']
#
# {"Current assets": "nan", "Cash at bank and in hand": "20", "Net assets": "20", "Issued share capital": "nan", "20 Ordinary Shares 1 of &#163 each": "20", "Total Shareholder funds": "20"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIT2O.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 12', 'Net assets 12', 'Issued share capital', '12 Ordinary Shares 1 of Â£ each 12', 'Total Shareholder funds 12']
#
# {"Current assets": "nan", "Cash at bank and in hand": "12", "Net assets": "12", "Issued share capital": "nan", "12 Ordinary Shares 1 of &#163 each": "12", "Total Shareholder funds": "12"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZITQ8.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIUTL.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 2 2', 'Net assets 2 2', 'Tssued share capital', '2 Ordinary Shares 1 of Â£ each 2 2', 'Total Shareholder funds 2 2']
#
# {"Called up share capital not paid": "2", "Net assets": "2", "Tssued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIV4B.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 3 3', 'Net assets 3 3', 'Issued share capital', '3 Ordinary Shares 1 of Â£ each 3 3', 'Total Shareholder funds 3 3']
#
# {"Current assets": "nan", "Cash at bank and in hand": "3", "Net assets": "3", "Issued share capital": "nan", "3 Ordinary Shares 1 of &#163 each": "3", "Total Shareholder funds": "3"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIVMX.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIW68.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIWEH.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 6 6', 'Net assets 6 6', 'Tssued share capital', '6 Ordinary Shares 1 of Â£ each 6 6', 'Total Shareholder funds 6 6']
#
# {"Called up share capital not paid": "6", "Net assets": "6", "Tssued share capital": "nan", "6 Ordinary Shares 1 of &#163 each": "6", "Total Shareholder funds": "6"}
#
# ----------------------------------------------------------------------------------------------
#
# X8XZIWI2.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current Assets 52,167 50,960', 'Creditors: amounts falling due within one year (16,402) (17,778)', 'Net current assets (liabilities) 35,765 33,182', 'Total assets less current liabilities 35,765 33,182', 'Total net assets (liabilities) 35,765 33,182', 'Capital and reserves 35,765 33,182']
#
# {"Current Assets": "52167", "Creditors: amounts falling due within one year": "-16402", "Net current assets (liabilities)": "35765", "Total assets less current liabilities": "35765", "Total net assets (liabilities)": "35765", "Capital and reserves": "35765"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y26BQO.txt
# 2019 2018
# ['2019', '2018']
# ['Called up share capital not paid 100 100', 'Net assets 100 100', 'Tssued share capital', '100 Ordinary Shares 1 of Â£ each 100 100', 'Total Shareholder funds 100 100']
#
# {"Called up share capital not paid": "100", "Net assets": "100", "Tssued share capital": "nan", "100 Ordinary Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y26QBM.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Current Assets 26,772 14,753', 'Creditors: amounts falling due within one year (1,612) (1,526)', 'Net current assets (liabilities) 25,160 13,227', 'Total assets less current liabilities 25,160 13,227', 'Accruals and deferred income (1,800) (1,000)', 'Total net assets (liabilities) 23,360 12,227', 'Capital and reserves 23,360 12,227']
#
# {"Current Assets": "26772", "Creditors: amounts falling due within one year": "-1612", "Net current assets (liabilities)": "25160", "Total assets less current liabilities": "25160", "Accruals and deferred income": "-1800", "Total net assets (liabilities)": "23360", "Capital and reserves": "23360"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28615.txt
# 2020 2019
# ['2020', '2019']
# ['Called up share capital not paid 1 1', 'Net assets 1 1', 'Tssued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Called up share capital not paid": "1", "Net assets": "1", "Tssued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y2878B.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 55 69', 'Current assets 38,369 40,804', 'Creditors: amounts falling due within one year - (8,177)', 'Net current assets 38,369 32,627', 'Total assets less current liabilities 38,424 32,696', 'Provisions for liabilities (9,044) (13,011)', 'Accruals and deferred income (860) (1,665)', 'Net assets 28,520 18,020', 'Capital and reserves 28,520 18,020']
#
# {"Fixed assets": "55", "Current assets": "38369", "Creditors: amounts falling due within one year": "-", "Net current assets": "38369", "Total assets less current liabilities": "38424", "Provisions for liabilities": "-9044", "Accruals and deferred income": "-860", "Net assets": "28520", "Capital and reserves": "28520"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y287W0.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 100', 'Net assets 100', 'Issued share capital', '100 Ordinary A Shares 1 of Â£ each 100', 'Total Shareholder funds 100']
#
# {"Current assets": "nan", "Cash at bank and in hand": "100", "Net assets": "100", "Issued share capital": "nan", "100 Ordinary A Shares 1 of &#163 each": "100", "Total Shareholder funds": "100"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y289DK.txt
# 2019 2018
# ['2019', '2018']
# ['Current assets', 'Cash at bank and in hand 2 2', 'Net assets 2 2', 'Issued share capital', '2 Ordinary Shares 1 of Â£ each 2 2', 'Total Shareholder funds 2 2']
#
# {"Current assets": "nan", "Cash at bank and in hand": "2", "Net assets": "2", "Issued share capital": "nan", "2 Ordinary Shares 1 of &#163 each": "2", "Total Shareholder funds": "2"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28A2W.txt
# Notes 2019 2018
# ['2019', '2018']
# ['Fixed Assets 11,779 13,397', 'Current Assets 43,205 18,499', 'Creditors: amounts falling due within one year (14,407) (22,226)', 'Net current assets (liabilities) 28,798 (3,727)', 'Total assets less current liabilities 40,577 9,670', 'Total net assets (liabilities) 40,577 9,670', 'Capital and reserves 40,577 9,670']
#
# {"Fixed Assets": "11779", "Current Assets": "43205", "Creditors: amounts falling due within one year": "-14407", "Net current assets (liabilities)": "28798", "Total assets less current liabilities": "40577", "Total net assets (liabilities)": "40577", "Capital and reserves": "40577"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28AFV.txt
# 2019 2018
# ['2019', '2018']
# ['Net assets 0 0', 'Reserves 0 0']
#
# {"Net assets": "0", "Reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28AR5.txt
# Notes 2019
# ['2019']
# ['Called up share capital not paid -', 'Fixed Assets -', 'Current Assets -', 'Prepayments and accrued income -', 'Creditors: amounts falling due within one year 0', 'Net current assets (liabilities) 0', 'Total assets less current liabilities 0', 'Creditors: amounts falling due after more than one year 0', 'Provisions for liabilities 0', 'Accruals and deferred income 0', 'Total net assets (liabilities) 0', 'Capital and reserves 0']
#
# {"Called up share capital not paid": "-", "Fixed Assets": "-", "Current Assets": "-", "Prepayments and accrued income": "-", "Creditors: amounts falling due within one year": "0", "Net current assets (liabilities)": "0", "Total assets less current liabilities": "0", "Creditors: amounts falling due after more than one year": "0", "Provisions for liabilities": "0", "Accruals and deferred income": "0", "Total net assets (liabilities)": "0", "Capital and reserves": "0"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28AVS.txt
# 2020 2019
# ['2020', '2019']
# ['Current assets', 'Cash at bank and in hand 1 1', 'Net assets 1 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1 1', 'Total Shareholder funds 1 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28BDM.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 1', 'Net assets 1', 'Issued share capital', '1 Ordinary Share 1 of Â£ each 1', 'Total Shareholder funds 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "1 Ordinary Share 1 of &#163 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28C76.txt
# 2019 2018
# ['2019', '2018']
# ['Fixed assets 4,608 5,720', 'Current assets 62,447 57,775', 'Prepayments and accrued income 785 654', 'Creditors: amounts falling due within one year (25,103) (25,733}', 'Net Current Assets 38,129 32,696', 'Total assets less current liabilities 42,737 38,416', 'Accruals and deferred income 1,608 1,902', 'Net Assets 41,131 36,514', 'Capital and reserves 41,131 36,514']
#
# {"Fixed assets": "4608", "Current assets": "62447", "Prepayments and accrued income": "785", "Creditors: amounts falling due within one year (25,103) (25,733}": "nan", "Net Current Assets": "38129", "Total assets less current liabilities": "42737", "Accruals and deferred income": "1608", "Net Assets": "41131", "Capital and reserves": "41131"}
#
# ----------------------------------------------------------------------------------------------
#
# X8Y28CDT.txt
# 2019
# ['2019']
# ['Current assets', 'Cash at bank and in hand 1', 'Net assets 1', 'Issued share capital', '100 Ordinary Shares of Â£ 0.01 each 1', 'Total Shareholder funds 1']
#
# {"Current assets": "nan", "Cash at bank and in hand": "1", "Net assets": "1", "Issued share capital": "nan", "100 Ordinary Shares of &#163 0.01 each": "1", "Total Shareholder funds": "1"}
#
# ----------------------------------------------------------------------------------------------
